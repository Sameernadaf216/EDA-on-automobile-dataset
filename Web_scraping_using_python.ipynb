# %% [markdown]
# ## **Problem Statement: Navigating the Data Science Job Landscape**
#
# 🚀 Unleash your creativity in crafting a solution that taps into the heartbeat of the data science job market! Envision an ingenious project that seamlessly wields cutting-edge web scraping techniques and illuminating data analysis.
#
# 🔍 Your mission? To engineer a tool that effortlessly gathers job listings from a multitude of online sources, extracting pivotal nuggets such as job descriptions, qualifications, locations, and salaries.
#
# 🧩 However, the true puzzle lies in deciphering this trove of data. Can your solution discern patterns that spotlight the most coveted skills? Are there threads connecting job types to compensation packages? How might it predict shifts in industry demand?
#
# 🎯 The core objectives of this challenge are as follows:
#
# 1. Web Scraping Mastery: Forge an adaptable and potent web scraping mechanism. Your creation should adeptly harvest data science job postings from a diverse array of online platforms. Be ready to navigate evolving website structures and process hefty data loads.
#
# 2. Data Symphony: Skillfully distill vital insights from the harvested job listings. Extract and cleanse critical information like job titles, company names, descriptions, qualifications, salaries, locations, and deadlines. Think data refinement and organization.
#
# 3. Market Wizardry: Conjure up analytical tools that conjure meaningful revelations from the gathered data. Dive into the abyss of job demand trends, geographic distribution, salary variations tied to experience and location, favored qualifications, and emerging skill demands.
#
# 4. Visual Magic: Weave a tapestry of visualization magic. Design captivating charts, graphs, and visual representations that paint a crystal-clear picture of the analyzed data. Make these visuals the compass that guides users through job market intricacies.
#
# 🌐 While the web scraping universe is yours to explore, consider these platforms as potential stomping grounds:
#
# * LinkedIn Jobs
# * Indeed
# * Naukri
# * Glassdoor
# * AngelList
#
# 🎈 Your solution should not only decode the data science job realm but also empower professionals, job seekers, and recruiters to harness the dynamic shifts of the industry. The path is open, the challenge beckons – are you ready to embark on this exciting journey?

# %% [markdown]
# Github Link: https://github.com/Sameernadaf216/Web-scraping-using-python

# %% [markdown]
# ## **Import Libraries**

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import plotly.express as px
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)

# %% [markdown]
# ## **Extracting Data from Website**

# %% [markdown]
# **Choosing the Timesjobs website for our scrape Mid Course Summative Assessment. Because from that website we can extract the job descriptions, skills, locations, and salaries which we want in our EDA and which is mention in problem statement.**

# %%
# First let we create the dataframe in which we will store our website data.
df=pd.DataFrame(columns = ['Company_Name' , 'Skills_Required', 'Job_Publish_Date', 'mix', 'Apply_link' ])

# Iterate through 10 pages of the job search results.
for page in range(1,11):

    # Fetching the HTML content of the job search page for the current page number.
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?from=submit&actualTxtKeywords=Data%20Science&searchBy=0&rdoOperator=OR&searchType=personalizedSearch&txtLocation=Bengaluru/%20Bangalore&luceneResultSize=25&postWeek=60&txtKeywords=data%20science&pDate=I&sequence='+str(page)+'&startPage=1').text

    # Parsing the HTML content using BeautifulSoup with 'lxml' parser
    soup = BeautifulSoup(html_text, 'lxml')

    # Finding all job listings on the current page
    jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

    # Iterating through each job listing and extract relevant information
    for job in jobs:

        # Extract company name
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace('\r\n', '').strip()

        # Extract skills required for the job
        skills = job.find('span', class_ = 'srp-skills').text.replace('\r\n', '').strip()

        # Extract job publish date
        job_publish_date = job.find('span', class_ = 'sim-posted').text.replace('\r', '').replace('Posted ', '').replace('\t', '').replace('\n', '').strip()

        # Extract additional information like locatoin, salary, experince
        mix = job.find('ul',class_="top-jd-dtl clearfix").text.replace('\r\n', '').strip()

        # Extract the link to the job posting for more information
        more_info = job.header.h2.a['href']

        # Appending the extracted data to the DataFrame as a new row
        simple_list=[[company_name, skills, job_publish_date,mix,more_info]]
        df = df.append(pd.DataFrame( simple_list,
                   columns=['Company_Name' , 'Skills_Required', 'Job_Publish_Date', 'mix', 'Apply_link' ]),
                   ignore_index = True)

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## ***Data Wrangling & Data Pre-processing***

# %%
# Dataset First Look
df.head()
# Out:
#                        Company_Name  \
# 0  LTIMindtree Ltd.     (More Jobs)
# 1                       Informatica
# 2                       Informatica
# 3                       Informatica
# 4                       Informatica
#
#                                      Skills_Required Job_Publish_Date  \
# 0  LLM  ,  "Large language model"  ,  Datascience...       3 days ago
# 1  data science   ,   machine learning   ,   natu...       6 days ago
# 2  data science   ,   machine learning   ,   natu...       6 days ago
# 3  machine learning   ,   natural language proces...       6 days ago
# 4  machine learning   ,   natural language proces...       6 days ago
#
#                                                  mix  \
# 0  card_travel7 - 12 yrs\n₹Rs 15.00 - 35.00 Lacs ...
# 1  card_travel3 - 5 yrs\n\nlocation_on\nBengaluru...
# 2  card_travel3 - 5 yrs\n\nlocation_on\nBengaluru...
# 3  card_travel3 - 5 yrs\n\nlocation_on\nBengaluru...
# 4  card_travel3 - 5 yrs\n\nlocation_on\nBengaluru...
#
#                                           Apply_link
# 0  https://www.timesjobs.com/job-detail/data-scie...
# 1  https://www.timesjobs.com/job-detail/member-da...
# 2  https://www.timesjobs.com/job-detail/member-da...
# 3  https://www.timesjobs.com/job-detail/member-da...
# 4  https://www.timesjobs.com/job-detail/member-da...

# %%
# Printing the unique values for the company name
df['Company_Name'].unique()
# Out:
# array(['LTIMindtree Ltd.     (More Jobs)', 'Informatica',
#        'TE Connectivity Ltd', 'Kpro Solutions', 'NUWARE SYSTEMS PVT LTD',
#        'CTE', 'HR Jobs Placements     (More Jobs)', 'OnMobile Global Ltd',
#        '2COMS Consulting Pvt Ltd     (More Jobs)',
#        'SAMPOORNA CONSULTANTS PVT LTD     (More Jobs)', 'Cotocus',
#        'Alpha Tech     (More Jobs)', 'Ravi     (More Jobs)',
#        'SN WEB ENTERPRISES     (More Jobs)',
#        'NeenOpal Intelligent Solutions Private Limited',
#        'pegasus knowledge solutions india pvt ltd.', 'boomerang commerce',
#        'MANOJ JOSHI     (More Jobs)', 'bdo rise private limited',
#        'Teach For India',
#        'Minanshika Softech Solution Pvt. Ltd.     (More Jobs)',
#        'Exxonmobil Company India Pvt Ltd', 'Nielsen Research Ltd. Co.',
#        'Sigmoid', 'ZYNGA', 'jumbotail',
#        'Deepanshu Sharma     (More Jobs)', 'Jumbotail Technologies',
#        'Arti     (More Jobs)',
#        'GENIQUE MANAGEMENT SERVICES PRIVATE LIMITED     (More Jobs)',
#        'Uplers Solutions Private Limited     (More Jobs)',
#        'job junction     (More Jobs)', 'Anamika Mahato     (More Jobs)',
#        'KIMSIS TECHNOLOGIES PRIVATE LIMITED     (More Jobs)',
#        'L and T Technology Services', 'Randstad MENA',
#        'the modern dimension',
#        'Phoenix Global Resettlement Services Pvt Ltd     (More Jobs)',
#        'Hotstar', 'Great Learning', 'ORMAE LLP', 'Clarivate Analytics',
#        'HyreFox Consultants',
#        'HAPPY SQUARE OUTSOURCING SERVICES PVT.LTD.     (More Jobs)',
#        'ERM Placement Services Pvt. Ltd.     (More Jobs)',
#        'freshworks technologies ltd',
#        'COLT TECHNOLOGY SERVICES INDIA PVT LTD',
#        'infinity business solutions pvt ltd',
#        'Information Services Group', 'ai enterprise',
#        'aeries technology group  ( sabre industries )',
#        'string bio pvt. ltd', 'SBM OFFSHORE', 'Kwalee',
#        'alliance recruitment agency', 'BizViz Technologies',
#        'Travel Centric Technology',
#        'CIGNEX Datamatics Technologies Pvt Ltd',
#        'netskope software pvt.ltd', 'Viraj Infotech     (More Jobs)',
#        'HR Empower Consultancy     (More Jobs)',
#        'Cynosure Corporate Solutions     (More Jobs)',
#        'Busibud Solutions Pvt. Ltd     (More Jobs)',
#        'Best Infosystems Ltd.     (More Jobs)',
#        'm / s simplex infrastructures ltd', 'brandmuscle india pvt ltd',
#        'ACUVATE SOFTWARE PVT LTD', 'PUBLICIS GROUPE',
#        'bekaert india technical center', 'krazy mantra hr solutions',
#        'sigmoid analutics', 'Ideapoke', 'Nineleaps',
#        'ASM Technologies Limited', 'Lucini & Lucini Communications',
#        'Infostretch Solution Pvt Ltd', 'AS Placement     (More Jobs)',
#        'Sarosh Karki     (More Jobs)',
#        'Namrata Bhatnagar     (More Jobs)', 'AugmatrixGo',
#        'covalent trainings', 'eurofins it solutions pvt ltd',
#        'SRIJAN TECHNOLOGIES', 'Patel Sandip Ranjitbhai     (More Jobs)',
#        'White Horse Manpower Consultancy P Ltd     (More Jobs)',
#        'A2Z Faculty     (More Jobs)', 'Laxmi Infotech     (More Jobs)',
#        'iron mountain india pvt ltd',
#        'Xpetize Technology Solutions Private Limited',
#        'beechi vidya kendra', 'BitByBit Solutions     (More Jobs)',
#        'crescendo global'], dtype=object)

# %%
# As we can see that some company name contain '(more jobs)' after there name therefore we have clean them.

# Removing '(More Jobs)' from the 'Company_Name' column
df['Company_Name'] = df['Company_Name'].str.replace(r'\s+\(More Jobs\)', '', regex=True)

# String extra space for each row
df['Company_Name'].apply(str.strip)

# Printing the unique values for the company name
df['Company_Name'].unique()
# Out:
# array(['LTIMindtree Ltd.', 'Informatica', 'TE Connectivity Ltd',
#        'Kpro Solutions', 'NUWARE SYSTEMS PVT LTD', 'CTE',
#        'HR Jobs Placements', 'OnMobile Global Ltd',
#        '2COMS Consulting Pvt Ltd', 'SAMPOORNA CONSULTANTS PVT LTD',
#        'Cotocus', 'Alpha Tech', 'Ravi', 'SN WEB ENTERPRISES',
#        'NeenOpal Intelligent Solutions Private Limited',
#        'pegasus knowledge solutions india pvt ltd.', 'boomerang commerce',
#        'MANOJ JOSHI', 'bdo rise private limited', 'Teach For India',
#        'Minanshika Softech Solution Pvt. Ltd.',
#        'Exxonmobil Company India Pvt Ltd', 'Nielsen Research Ltd. Co.',
#        'Sigmoid', 'ZYNGA', 'jumbotail', 'Deepanshu Sharma',
#        'Jumbotail Technologies', 'Arti',
#        'GENIQUE MANAGEMENT SERVICES PRIVATE LIMITED',
#        'Uplers Solutions Private Limited', 'job junction',
#        'Anamika Mahato', 'KIMSIS TECHNOLOGIES PRIVATE LIMITED',
#        'L and T Technology Services', 'Randstad MENA',
#        'the modern dimension',
#        'Phoenix Global Resettlement Services Pvt Ltd', 'Hotstar',
#        'Great Learning', 'ORMAE LLP', 'Clarivate Analytics',
#        'HyreFox Consultants',
#        'HAPPY SQUARE OUTSOURCING SERVICES PVT.LTD.',
#        'ERM Placement Services Pvt. Ltd.', 'freshworks technologies ltd',
#        'COLT TECHNOLOGY SERVICES INDIA PVT LTD',
#        'infinity business solutions pvt ltd',
#        'Information Services Group', 'ai enterprise',
#        'aeries technology group  ( sabre industries )',
#        'string bio pvt. ltd', 'SBM OFFSHORE', 'Kwalee',
#        'alliance recruitment agency', 'BizViz Technologies',
#        'Travel Centric Technology',
#        'CIGNEX Datamatics Technologies Pvt Ltd',
#        'netskope software pvt.ltd', 'Viraj Infotech',
#        'HR Empower Consultancy', 'Cynosure Corporate Solutions',
#        'Busibud Solutions Pvt. Ltd', 'Best Infosystems Ltd.',
#        'm / s simplex infrastructures ltd', 'brandmuscle india pvt ltd',
#        'ACUVATE SOFTWARE PVT LTD', 'PUBLICIS GROUPE',
#        'bekaert india technical center', 'krazy mantra hr solutions',
#        'sigmoid analutics', 'Ideapoke', 'Nineleaps',
#        'ASM Technologies Limited', 'Lucini & Lucini Communications',
#        'Infostretch Solution Pvt Ltd', 'AS Placement', 'Sarosh Karki',
#        'Namrata Bhatnagar', 'AugmatrixGo', 'covalent trainings',
#        'eurofins it solutions pvt ltd', 'SRIJAN TECHNOLOGIES',
#        'Patel Sandip Ranjitbhai',
#        'White Horse Manpower Consultancy P Ltd', 'A2Z Faculty',
#        'Laxmi Infotech', 'iron mountain india pvt ltd',
#        'Xpetize Technology Solutions Private Limited',
#        'beechi vidya kendra', 'BitByBit Solutions', 'crescendo global'],
#       dtype=object)

# %%
# Printing the unique values for the Skills_Required
df['Skills_Required'].unique()
# Out:
# array(['LLM  ,  "Large language model"  ,  Datascience  ,  azure  ,  "data scientist"  ,  datascientist',
#        'data science   ,   machine learning   ,   natural language processing   ,   advanced analytics   ,   big data   ,  data mining  ,  sql  ,  hadoop  ,  mongodb  ,  python  ,  sas  ,  cassandra  ,  entry level',
#        'machine learning   ,   natural language processing   ,   data science tools   ,   advanced analytics   ,   generative ai   ,  data mining  ,  sql  ,  hadoop  ,  big data  ,  mongodb  ,  python  ,  sas  ,  cassandra  ,  entry level',
#        'data science   ,   digital manufacturing   ,   ml  /  ai  /  dl   ,   data visualization   ,   database skills   ,  information technology  ,  java  ,  big data  ,  python  ,  algorithms  ,  pattern recognition  ,  team player  ,  machine learning  ,  consultant',
#        'python  ,  sas  ,  sql  ,  data extraction  ,  hadoop',
#        'python  ,  rdbms  ,  data mining  ,  machine learning  ,  sql  ,  senior software developer  ,  software developer',
#        'fundamentals  ,  algorithms  ,  python  ,  machine learning  ,  debugging  ,  big data',
#        'Data Science Analyst  ,  Data Science  ,  test model quality  ,  product development  ,   marketing techniques  ,  customer experiences  ,   revenue generation  ,   ad targeting',
#        'python  ,   restful apis  ,   machine learning  ,   html5  ,   javascript   ,  senior software engineer  ,  git',
#        'python developer  ,   python programming', 'Data science',
#        'Data Science  ,  Machine Learning  ,  SQL  ,  NoSQL  ,  Python  /   Spark  /   R Data Science Stack',
#        'machine learning  ,  docker  ,   data science',
#        'TDD  ,  Deep Learnig  ,  Deployment  ,  Mongo DB  ,  SQL  ,  Python  ,  Data Analyst  ,  business analyst  ,  Tableau  ,  Spss  ,  Data Analysis  ,  Data Cleaning  ,  Statistical Analysis  ,  Data Validation  ,  MIS',
#        'chat support  ,  Email Support  ,  Chat Process  ,  Non Voice  ,  Bpo  ,  Customer Care  ,  Back Office  ,  Live Chat  ,  Web Chat  ,  Customer Service  ,  Email  ,  Customer Care Representative',
#        '12TH PASSCOMPUTER OPERATORDATA ENTRYHOME BASED WORKFREELANCERFRESHERSGRADUATE',
#        'spss  ,  data warehousing  ,  sql  ,  data science  ,  data visualization  ,  advanced analytics  ,  solution architect  ,  sas  ,  tableau  ,  project delivery',
#        'Freelancer  ,  part time  ,  Work From Home  ,  Data Entry Operator  ,  Back Office Support  ,  CHAT SUPPORT  ,  Email Support  ,  Chat Process  ,  Email  ,  Live Chat  ,  Customer Support  ,  Ms Office',
#        '12th pass  ,   home based  ,  back office  ,  back office executive  ,  customer support executive  ,  csr',
#        'Computer Operator  ,  data entry operator  ,  Typing  ,  Ms Office  ,  Touch Typing  ,  Erp  ,  Operation  ,  Data  ,  Internet  ,  Word  ,  Microsoft  ,  Back Office  ,  mis executive  ,  backend executive  ,  WPM',
#        'data mining  ,  anova  ,  spss  ,  data science  ,  use cases  ,  data scientist  ,  arima  ,  data analytics  ,  sas  ,  written communication',
#        'data science  ,   machine learning  ,   statistics  ,   python  ,   r   ,  information technology  ,  data mining  ,  sql  ,  cloud services',
#        'data science  ,   machine learning  ,   statistical analysis  ,   data visualization  ,   python coding   ,  data analysis  ,  dashboards  ,  tableau  ,  data scientist',
#        'computer operator  ,  data entry  ,  Ticketing  ,  Cabin crew  ,  HR  ,  Iti Electrician  ,  Hospitality Tourism  ,  Ground staff  ,  customer services  ,  Back office  ,  team leader  ,  IT Operations',
#        'visualization  ,  bi  ,  dashboards  ,  sql  ,  data science  ,  data visualization  ,  advanced analytics  ,  data analytics  ,  analyst',
#        'spss  ,  data science  ,  data analytics  ,  data analysis  ,  tableau  ,  consultant',
#        'data scientist  ,  data science  ,  senior data scientist  ,  java  ,  r  ,  nlp  ,  Data Modeling  ,  ExtJS  ,  Spark  ,  Python',
#        'Data Entry Operator  ,  Data Entry  ,  Computer Operator  ,  Computer Data Entry  ,  Data Entry   /  Computer Operator  ,  Work From Home  ,  Work from Home data Entry  ,  Online Data Entry',
#        'data science  ,   machine learning  ,   statistical analysis  ,   python  &  r  ,   software engineering   ,  devops  ,  software testing  ,  ensemble  ,  security  ,  pattern recognition  ,  natural language processing',
#        'data science   ,   python   ,   spark   ,   sql   ,   aws   ,  fundamentals  ,  git  ,  debugging  ,  software engineering  ,  machine learning  ,  written communication  ,  production environment  ,  unix',
#        'data science   ,   machine learning   ,   ai and analytics   ,   python programming   ,   client engagement   ,  algorithms  ,  data mining  ,  artificial intelligence  ,  sql  ,  it management  ,  san  ,  nosql',
#        'Airport Handling Operation Ground Handling  ,  Armed Security Officer  ,  Fire Safety  ,  Admin Manager  ,  Computer Operator  ,  data entry  ,  data entry operator  ,  operator',
#        '12TH PASS  ,   FRELANCER  ,   FRESHER  ,  Computer Operator  ,  data entry  ,  team leader  ,  Ms Office',
#        'data analysis  ,   data science  ,   sql  ,   python  ,   machine learning   ,  games  ,  messaging  ,  hadoop  ,  san',
#        'FRESHER  ,  trainee  ,  customer service  ,  customer service executive  ,  supervisor  ,  computer supervisor  ,  Data Entry Operator',
#        'computer operator  ,  data entry operator  ,  operator  ,  executive  ,  mis executive  ,  backend executive',
#        '12TH PASS  ,   FRELANCER  ,   FRESHER  ,  Computer Operator  ,  data entry  ,  team leader',
#        'data mining  ,  sql  ,  team player',
#        'Payroll  ,  Management   ,  Store incharge   ,  Store Keeper   ,  Supervisor   ,  Data Entry   ,  Guard   ,  Airport   ,  Airlines   ,  Passport Checker   ,  Ticketing   ,  Ground Staaf   ,  Airport Jobs',
#        'data mining  ,  sql  ,  data visualization  ,  data analysis  ,  pricing models  ,  tableau  ,  analyst',
#        'ground staff  ,  computer operator  ,  data entry  ,  passport  ,  Inspection  ,  bpo  ,  Back-office Operations  ,  Customer Care  ,  Admin And Hr  ,  Non Voice  ,  Operations  ,  Supply Chain  ,  Kpo',
#        'Ground staff  ,  computer operator  ,  data entry  ,  Ticketing   ,  Airlines  ,  Cabin crew  ,  Hospitality Tourism  ,  Security   ,  Hr  ,  Human Resourcs  ,  Back office  ,  team leader  ,  Airport   ,  BPO',
#        'Electrical Mechanical Maintenance  ,  electronics  ,  Telecommunications  ,  Data Communication  ,  Electrical Maintenance  ,  power  ,  Electrical  ,  Auto Cad  ,  Electrical Power System',
#        'Healthcare  ,  Healthcare Management  ,  Hospital Administration  ,  Operations  ,  Claims  ,  provider data management  ,  Customer Success  ,  Client Servicing  ,  client servicing executive',
#        'PECI  ,  PICOF  ,  Workday',
#        'React  ,  Shopify  ,  Git  ,  ROR  ,  Shopify Liquid  ,  Javascript  ,  Node  ,  Python',
#        'Ground staffDomestic TicketingAirline TicketingReservationsTicketingCabin crewBack Office Operationscomputer operatorHospitality Tourism',
#        'Microsoft Identity  ,  IDM domain  ,  ITIL  ,  ITIL v4  ,  L3 technical  ,  Active Directory  ,  MIMWAL  ,  PowerShell  ,  Microsoft SQL',
#        'branch manager  ,  branch incharge  ,  branch head  ,  insurance sales  ,  Life Insurance  ,  General Insurance  ,  Health Insurance  ,  Sales Manager  ,  territory sales manager  ,  DIRECT SALES  ,',
#        '"SaaS Technica"  ,  "Fusion Technical"  ,  "Cloud Technical"',
#        '"Fusion HCM"  ,  "SaaS HCM"  ,  "Cloud HCM"  ,  "Solution Architect"  ,  "Architect"',
#        '"Oracle Learning Cloud"  ,  "Fusion HCM"  ,  "SaaS HCM"  ,  "Cloud HCM"  ,  "OLC"',
#        '"Oracle Recruitment Cloud"  ,  "ORC"',
#        '"Fusion HCM"  ,  "SaaS HCM"  ,  "Cloud HCM"',
#        '"Cloud Projects portfolio Management"  ,  "SaaS Projects portfolio Management"  ,  "Fusion Projects portfolio Management"',
#        '"SaaS OTM"  ,  "Cloud OTM"  ,  "SaaS GTM"  ,  "Fusion GTM"  ,  "Cloud GTM"  ,  "Cloud Global Transportation Management"  ,  "Global Transportation Management"  ,  "Fusion OTM"',
#        '"SaaS Technical"  ,  "Fusion Technical"  ,  "Cloud Technical"  ,  Cloud Computing',
#        'Oracle Production Support  ,  Payment  ,  Banking',
#        '"PSFT Admin"  ,  "PSFT DBA"  ,  "PeopleSoft Admin"  ,  "PeopleSoft DBA"  ,  "Integration Broker"  ,  IB  ,  Upgradetion',
#        'Communication skills  ,  Creative skills  ,  Computer skills  ,  Teamwork skills  ,  Problem-solving skills',
#        'java  ,  react  ,  javasc  ,  css  ,  html  ,  angular  ,  php  ,  jquery  ,  c#  ,  Mean Stack  ,  Mern Stack  ,  Full Stack  ,  LAMP  ,  Lamp Stack  ,  python  ,  Python Scripting  ,  Sql  ,  Saas  ,  AWS  ,  Azure  ,  GCP  ,  Oracle',
#        'full stack  ,  java  ,  Html  ,  css  ,  .net  ,  javascript  ,  php  ,  Database  ,  sql  ,  oracle  ,  reactjs  ,  angularjs  ,  Bootstrap  ,  c#  ,  asp.net  ,  nodejs  ,  Mongodb  ,  Python',
#        'IT',
#        'html  ,  css  ,  Xml  ,  php  ,  angular  ,  react  ,  java  ,  javascript  ,  Dhtml  ,  Sql  ,  Core Java  XML  ,  c ++',
#        'data analytics   ,   data visualization   ,   business intelligence   ,   statistical  /  ml techniques   ,   team management   ,  san  ,  advanced analytics  ,  spotfire  ,  bi  ,  data analyst  ,  tableau  ,  data science  ,  client interaction  ,  sql database',
#        'Clinical Trial  ,  Clinical Research  ,  Pharmacovigilance  ,  Clinical Data Management  ,  Clinical Research Associate  ,  Regulatory Affairs  ,  Uv  ,  Hplc  ,  Calibration  ,  Biotechnology  ,  Dna',
#        'Human Resource Management  ,  Recruitment  ,  hr executive  ,  hr recruiter  ,  MBA  ,  Hr Operations  ,  Hr Generalist  ,  IT recruiter  ,  Hr Assistance  ,  Hr Administration  ,  Hr Admin  ,  Payroll  ,  Hr',
#        'Waterfall  ,  Scrum  ,  Agile Methodologies  ,  Software Project Management  ,  Hybrid  ,  Kanban  ,  MicrosoftTechnology Stack  ,  Big Data  ,  Analytics  ,  Scope  ,  Project',
#        'Azure Analysis Services  ,  Amazon Aws  ,  Devops  ,  Jenkins  ,  Power Bi Desktop  ,  Power Query  ,  Power Bi  ,  Business Analysis  ,  Dax Queries  ,  Sql  ,  Spss  ,  Statistics  ,  Business Intelligence',
#        'hazardous materials handling   ,   lithium ion batteries   ,   materials analysis   ,   microscopy and sem   ,   data analysis and reporting    ,  problem solving  ,  technical skills',
#        'business administration   ,   computer science   ,   data science   ,   product management   ,   agile methodologies   ,  writing  ,  jira',
#        'Information Systems  ,   Computer Science  ,   Computer Engineering  ,  Software Engineering',
#        'Analytical studies  ,  sparkSQL  ,  Data scientist  ,  Artificial Intelligence',
#        'business requirements  ,  information technology  ,  bi  ,  data warehousing  ,  dashboards  ,  data science  ,  business analysis  ,  tableau',
#        'product management  ,   customer experience  ,   market share  ,   data science  ,   communication skills   ,  product development  ,  innovation  ,  ideas  ,  license  ,  spm',
#        'product management   ,   business administration   ,   technical background   ,   agile methodologies   ,   data science   ,  writing  ,  jira  ,  validation testing',
#        'product analytics   ,   data science   ,   r   ,   sql   ,   python   ,  marketing campaigns  ,  marketing analytics  ,  digital analytics  ,  marketing initiatives',
#        'python  ,   data science  ,   ai  ,   cloud  ,   cyber security   ,  reports  ,  information technology  ,  cms  ,  content management',
#        'c    ,  spss  ,  java  ,  data science  ,  client facing  ,  advanced analytics  ,  genesys  ,  sas  ,  business analytics  ,  analyst',
#        'healthcare pharma  /  claims  ,   data analysis  ,   life sciences  ,   statistical research  ,   sas programming   ,  security  ,  data scientist  ,  data analyst  ,  statistical analysis',
#        'Testing  ,  Qa  ,  Qc  ,  Automation Testing  ,  Selenium  ,  Jira  ,  Core Java  ,  Manual Tester  ,  test engineer  ,  qa engineer  ,  qa lead  ,  it analyst  ,  Trainee  ,  Software Quality Testing  ,  Bug  ,  linux',
#        'business requirements  ,  business analyst  ,  sql  ,  process mapping  ,  data science  ,  brd  ,  data analysis  ,  requirement elicitation  ,  written communication  ,  visio',
#        'data science   ,   business consulting   ,   analytics   ,   ai   ,   dataops   ,  technology consulting  ,  cpg  ,  san  ,  customer analytics  ,  data analysis  ,  predictive analytics',
#        'Data scientist', 'snowflakes',
#        'data entry  ,  data management  ,  MS OFFICE  ,  Warehousing  ,  inventory management',
#        'computer skills', 'Data quality',
#        'machine learning  ,   data science  ,   software development  ,   numerical analysis  ,   regression analysis   ,  c    ,  sql  ,  security  ,  git  ,  devops  ,  python  ,  natural language processing',
#        'user experience design   ,   product design   ,   ux research   ,   data science   ,   engineering    ,  typography  ,  composition  ,  ux design  ,  mobile  ,  articulate  ,  motion graphics  ,  designing',
#        'reservoir engineering  ,   analytical skills  ,   reservoir simulation  ,   data science  ,   fluid mechanics   ,  python  ,  ipm  ,  eclipse  ,  storage  ,  security  ,  machine learning',
#        'visualization  ,  dashboards  ,  text analytics  ,  logistic regression  ,  advanced analytics  ,  data analytics  ,  data mining  ,  bi  ,  sql  ,  database  ,  data science  ,  product analyst  ,  data visualization  ,  cluster analysis  ,  crm  ,  san  ,  data analysis  ,  tableau',
#        'data analytics   ,   business insights   ,   data analysis   ,   visualization tools   ,   communication skills   ,  bi  ,  sql  ,  database  ,  data science  ,  use cases  ,  lead analyst  ,  predictive analytics  ,  data analyst  ,  tableau  ,  consultant  ,  infrastructure',
#        'data analytics   ,   data visualization   ,   business intelligence   ,   problem solving   ,   project management   ,  san  ,  advanced analytics  ,  bi  ,  dashboards  ,  tableau  ,  data science  ,  client interaction  ,  sql database',
#        'Agile   ,   UML   ,   Web Technologies   ,   Java   ,   Cloud   ,  java  ,  uml  ,  j2ee  ,  problem solving  ,  hl7  ,  web technologies  ,  software developer',
#        'Azure',
#        'data analysis   ,   python   ,   excel   ,   data visualization   ,   sql   ,  bi  ,  data extraction  ,  database  ,  git  ,  technical skills  ,  machine learning  ,  infrastructure  ,  data communication',
#        'algorithms  ,  python  ,  apache',
#        'algorithms  ,  python  ,  sas  ,  sql',
#        'hive  ,  fundamentals  ,  algorithms  ,  information technology  ,  data mining  ,  bi  ,  sql  ,  data extraction  ,  atg  ,  mongodb  ,  python  ,  rdbms  ,  machine learning  ,  nosql  ,  cassandra  ,  infrastructure',
#        'algorithms  ,  c    ,  data mining  ,  sql  ,  python',
#        'algorithms  ,  python  ,  data mining  ,  sql  ,  data structures  ,  big data',
#        'data analysis  ,   analytics  ,   python  ,   power bi  ,   visualization   ,  hive  ,  data extraction  ,  api  ,  oracle  ,  sas  ,  microsoft azure',
#        'data engineering  ,   etl  ,   informatica cloud  ,   machine learning  ,   python   ,  salesforce  ,  shell scripting  ,  github  ,  oracle  ,  director  ,  algorithms  ,  bi  ,  sql  ,  entry level  ,  forms',
#        'data engineering   ,   sql databases   ,   python automation   ,   cloud services   (  aws  )     ,   etl processes   ,  jam  ,  games  ,  simulator  ,  mobile  ,  infrastructure',
#        'data engineering   ,   sql databases   ,   python automation   ,   cloud services   ,   etl processes    ,  artificial intelligence  ,  jam  ,  games  ,  simulator  ,  mobile  ,  infrastructure',
#        '1  )   data stewardship 2  )   data strategy 3  )   data governance 4  )   data management 5  )   analytics capabilities   ,  information technology  ,  salesforce  ,  python  ,  data mining  ,  sql  ,  database  ,  sem  ,  crm  ,  team player',
#        'algorithms  ,  information technology  ,  data warehousing  ,  storage  ,  sql  ,  security  ,  java  ,  hadoop  ,  big data  ,  python  ,  nosql  ,  infrastructure',
#        'data mining  ,  sql  ,  data scientist  ,  predictive analysis  ,  advanced analytics  ,  data analysis  ,  sas  ,  author  ,  predictive analytics  ,  algorithm development  ,  statistical analysis',
#        'python  ,  c    ,  scala  ,  oozie  ,  sql  ,  nosql  ,  java  ,  cassandra  ,  hadoop  ,  big data',
#        'storage  ,  database  ,  adf  ,  python  ,  cl  ,  sql scripting  ,  sql database',
#        'information technology  ,  team player  ,  sql',
#        'scala  ,  bi  ,  sql  ,  security  ,  java  ,  devops  ,  technical skills  ,  python  ,  machine learning  ,  infrastructure',
#        'data systems architecture   ,   data systems engineering   ,   software engineering   ,   site reliability engineering   ,   data management   ,  c    ,  orchestration  ,  mysql  ,  python  ,  nosql  ,  cassandra  ,  openstack  ,  docker  ,  security  ,  mongodb  ,  infrastructure',
#        'Scrum Master  ,  Manufacturing and Automation  ,  Data Analytics',
#        'Data Modeling', 'Data Modeling  ,  data assessment',
#        'Data Analyst  ,  analyst  ,  senior analyst  ,  system analyst',
#        'OBIEE  ,    ,  SQL  ,  Business Intelligence Data Warehousing',
#        'support engineer  ,  data centre  ,  power cycling  ,  Rebooting  ,  Inventory management  ,  network connectivity  ,  BOM verification  ,  DCIM tool  ,  Amber LED  ,  Cable Dressing  ,  Infra Power',
#        'Data Engineer',
#        'Typing skills  ,  Ms Office  ,  ms word  ,  40 wpm  ,  Data Entry  ,  computer operator',
#        'azure  ,  python  ,  pyspark', 'Azure  ,  Data engineer',
#        'Data ingestion  ,  ETL  ,  Data Warehousing  ,  CDC  ,  Data Modeling  ,  Data Engineering',
#        'Business Analysis  ,  big data  ,  Agile Programming  ,  Scaled agile framework',
#        'Basic Computer Skills  ,  computer operator  ,  office assistant',
#        'ODI  ,  "Oracle Data Integrator"  ,  "Data warehousing"  ,  DWH',
#        'algorithms  ,  python  ,  machine learning  ,  sql  ,  d3.js  ,  data structures  ,  mongodb',
#        'learning acumen   ,   team management   ,   problem solver   ,   data interpretation   ,   machine learning   ,  algorithms  ,  information technology  ,  data extraction  ,  java  ,  linux  ,  big data  ,  san  ,  python',
#        'Data ingestion  ,  Databricks  ,  Datawarehouse  ,  Data Modeling  ,  Developing pipelines  ,  Azure Cloud Services',
#        'algorithms  ,  ds  ,  sql  ,  big data  ,  python  ,  machine learning',
#        'java   ,   python   ,   spark   ,   sql   ,   aws   ,  fundamentals  ,  git  ,  debugging  ,  software engineering  ,  big data  ,  machine learning  ,  written communication  ,  production environment  ,  unix',
#        'algorithms  ,  python  ,  machine learning  ,  sql  ,  d3.js  ,  mongodb',
#        'hive  ,  algorithms  ,  data mining  ,  sql  ,  pig  ,  mongodb  ,  hbase  ,  simulation models  ,  python  ,  machine learning  ,  nosql  ,  cassandra',
#        'bi  ,  data warehousing  ,  data architecture  ,  data marts  ,  sql  ,  data transformation  ,  etl  ,  data architect  ,  data quality',
#        'sql  ,  cloud computing  ,  python  ,  machine learning',
#        'software development   ,   big data   ,   cloud implementation   ,   sql   ,   agile scrum   ,  orchestration  ,  scala  ,  storage  ,  security  ,  java  ,  apache  ,  postgresql  ,  devops  ,  json  ,  shell scripting  ,  mysql  ,  technical skills  ,  python  ,  written communication  ,  unix  /  linux  ,  software developer',
#        'big data   ,   apache spark   ,   cloud implementation   ,   resilience   ,   agile scrum   ,  orchestration  ,  information technology  ,  java  ,  software engineering  ,  shell scripting  ,  mysql  ,  python  ,  oracle  ,  unix  /  linux  ,  hive  ,  scala  ,  docker  ,  security  ,  git  ,  postgresql  ,  json  ,  hadoop  ,  technical skills  ,  rdbms  ,  written communication',
#        'Java  ,   Scala  ,   Python  ,   MYSQL  ,   MS SQL  ,   NOSQL  ,   Columnar Databases  ,   Spark Streaming  ,   Apache Kafka  ,   design algorithms  ,   predictive analytics  ,  tenacity',
#        'quantitative analytics   ,   risk assessment   ,   fraud detection   ,   underwriting   ,   machine learning   ,  bi  ,  sql  ,  python',
#        'data architecture  ,   azure cloud services  ,   agile environment  ,   data modelling  ,   data integration patterns   ,  etl  ,  data profiling  ,  data engineer  ,  data quality  ,  data warehousing  ,  crm  ,  solution architect  ,  infrastructure  ,  sql database',
#        'Data Entry  ,  Data Entry Operator  ,  Work From Home  ,  Home base work  ,  Work From Home Data Entry  ,  Computer Operator  ,  Data Entry Computer Operator  ,  Home base job',
#        'data engineering  ,   aws  ,   etl scripting  ,   data warehousing  ,   sql   ,  python  ,  data mining  ,  node.js  ,  database  ,  big data',
#        'algorithms  ,  python  ,  informationtechnology  ,  team player  ,  machine learning  ,  data extraction  ,  java  ,  linux  ,  big data',
#        'data engineering   ,   sql   ,   nosql   ,   cloud services   ,   container technologies   ,  docker  ,  database  ,  git  ,  couchbase  ,  mysql  ,  big data  ,  technical skills  ,  mongodb  ,  oracle',
#        'algorithms  ,  artificial intelligence  ,  sql  ,  data extraction  ,  big data  ,  python  ,  natural language processing  ,  team player  ,  machine learning  ,  nosql',
#        'data services   ,   cloud native dbaas   ,   relational databases   ,   nosql   ,   communication skills    ,  technical leader  ,  information technology  ,  security  ,  rdbms  ,  infrastructure',
#        'machine learning   ,   search   ,   pattern recognition   ,   text mining   ,   big data   ,  conference  ,  data mining',
#        'data engineering   ,   etl solutions   ,   python   ,   sql   ,   spark   ,  hive  ,  algorithms  ,  storage  ,  pig  ,  apache  ,  git  ,  data structures  ,  dash',
#        'information technology  ,  sql  ,  database management  ,  security  ,  database  ,  technology management  ,  postgresql  ,  linux  ,  mysql  ,  pl  /  sql  ,  big data  ,  mongodb  ,  cloud services  ,  oracle  ,  microsoft azure  ,  production environment',
#        'machine learning  ,  artificial intelligence  ,  docker',
#        'css  ,  python  ,  c    ,  jquery  ,  javascript  ,  web development  ,  html',
#        'linux operating system  ,  sql scripting  ,  database  ,  php  ,  mysql  ,  unix',
#        'fundamentals  ,  sql  ,  database  ,  python scripting  ,  git  ,  devops  ,  software engineering  ,  python  ,  rdbms',
#        'aws  /  gcp  ,   ec2  ,   iam  ,   s3  ,   docker  ,   kubernetes  ,   jenkins  ,   prometheus  ,   python  ,   golang  ,   shell scripting  ,   networking  ,   relational databases  ,   non relational databases.   ,  fundamentals  ,  devops',
#        'ADF  ,  Synapse  ,  Azure data factory',
#        'Back Office Server  ,  accounts  ,  Financial Accounting  ,  Ms Office  ,  system administrator  ,  desktop support  ,  customer support engineer  ,  Collection Process',
#        'Google Big Query',
#        'Python Developer  ,  Java Developer  ,  software developer  ,  Network Engineer  ,  system engineer  ,  system administrator  ,  it executive',
#        'NUTRITION  ,  Food Processing  ,  Food Processing Industry  ,  Food Science  ,  Food Analysis  ,  Microbiology  ,  Clinical Nutrition  ,  Diet Planning  ,  Nutritionist  ,  Dietitian',
#        'Email  ,  CHAT SUPPORT  ,  Email Support  ,  Chat Process  ,  Non Voice  ,  Kpo  ,  Bpo  ,  Live Chat  ,  Back Office  ,  Web Chat  ,  AIR TICKETING  ,  International Ticketing  ,  Amadeus  ,  Ticket Booking',
#        'Typing Skill  ,  Communication skills  ,  MS Office',
#        'data analysis   ,   sql   ,   python programming   ,   machine learning   ,   communication skills   ,  games  ,  messaging  ,  hadoop  ,  san',
#        'algorithms  ,  python  ,  rdbms  ,  nosql  ,  written communication  ,  data structures  ,  hadoop  ,  big data',
#        'big data administration   ,   team management   ,   hadoop administration   ,   database management   ,   cloud services   ,  messaging  ,  mapreduce  ,  unix  /  linux  ,  hive  ,  cloudera  ,  data warehousing  ,  storage  ,  sql  ,  security  ,  technical skills  ,  oozie  ,  hdfs',
#        'data analysis   ,   python   ,   excel   ,   sql   ,   communication   ,  bi  ,  data extraction  ,  database  ,  git  ,  technical skills  ,  machine learning  ,  infrastructure  ,  data communication',
#        'medical writing  ,  clinical research  ,  regulatory affairs  ,  clinical data management  ,  clinical sas  ,  pharma  ,  pharmacovigilance',
#        'data engineering   ,   data warehousing   ,   etl  /  elt processes   ,   python   ,   jenkins ci  /  cd   ,  business rules  ,  devops  ,  software engineering  ,  api  ,  erp  /  crm  ,  nosql  ,  software design  ,  bi  ,  security  ,  data extraction  ,  git  ,  information management  ,  software delivery  ,  mobile  ,  infrastructure',
#        'data engineering   ,   information security   ,   etl  /  elt processes   ,   ci  /  cd platform   (  jenkins  )     ,   python  /  powershell   ,  business rules  ,  devops  ,  software engineering  ,  api  ,  erp  /  crm  ,  nosql  ,  software design  ,  bi  ,  data warehousing  ,  data extraction  ,  git  ,  information management  ,  software delivery  ,  mobile  ,  infrastructure',
#        'databricks   ,   pyspark   ,   sql   ,   microsoft azure   ,   data engineering   ,  orchestration  ,  bi  ,  storage  ,  python  ,  machine learning',
#        '12TH  ,  GRADUATE.  ,  BA  ,  B.com  ,   10TH  ,  WORK FROM HOME  ,  PART TIME  ,  Full Time  ,  Time Management  ,  Good Communication',
#        'Ms-office  ,  12TH PASS  ,  GRADUATE  ,  Fresher  ,  trainee  ,  customer service  ,  team leader  ,  system administrator',
#        'SAP MDG',
#        'Teamwork   ,  Problem - Solving  ,  Written Communication  ,   Leadership',
#        'FRESHER  ,  ADMINISTARTION  ,   12TH PASS  ,  COMPUTER OPERATOR  ,  operator  ,  data entry',
#        'FRESHER  ,   ADMINISTRATION  ,  Computer Operator  ,  office assistant  ,  assistant  ,  executive assistant',
#        '12th PASS OUT  ,  FRESHERS  ,  COMPUTER   /    SKILLS  ,  GRADUATE',
#        'SQL  ,   IBM Cognos  ,   Spotfire  ,   Knowledge of Scripting   (  XML  ,   Java Script  ,   Shell Scripting  ,   Perl etc  )',
#        'Manufacturing and Automation  ,  IoT - General Experience  ,  Cloud development  ,  Microservices architecture   (  MSA  )    ,  .net Core',
#        'Biology Teacher  ,  Science Teacher  ,  Maths Teacher  ,  Teaching  ,  Teacher',
#        'SAP  ,  SAPSD  ,  MASTER DATA MANAGEMENT',
#        'Data Entry  ,   Back Office  ,   Computer Operator',
#        'machine learning   ,   mathematical skills   ,   problem solving   ,   coding   ,   data visualization   ,  data mining  ,  storage  ,  sql  ,  database  ,  big data  ,  python  ,  cloud services  ,  information management  ,  forms',
#        'bigquery  ,   data studio  ,   data infrastructure management  ,   data analysis and visualization  ,   data integration and etl   ,  data warehousing  ,  storage  ,  sql  ,  security  ,  data extraction  ,  data services  ,  data quality',
#        'ERP Data Migration  ,   SAP Data Migration  ,   PLM Data Migration  ,   MDM  ,   Oracle ERP Data Migration   ,  functional analyst  ,  data migration  ,  pmp  ,  oracle erp  ,  crm  ,  master data  ,  sap  ,  solution architect  ,  workflow  ,  implementation  ,  written communication  ,  mdm  ,  mediator',
#        'airflow   ,   python   ,   spark   ,   sql   ,   nosql   ,  docker  ,  database  ,  git  ,  couchbase  ,  mysql  ,  big data  ,  technical skills  ,  mongodb  ,  oracle',
#        'airflow  ,   python  ,   spark  ,   database systems  ,   cloud service technologies   ,  sql  ,  docker  ,  git  ,  couchbase  ,  mysql  ,  big data  ,  technical skills  ,  mongodb  ,  oracle  ,  nosql',
#        'Java  ,   Python  ,   Scala  ,   Big Data  ,   Software Development   ,  algorithms  ,  information technology  ,  scala  ,  java  ,  oops  ,  software engineer  ,  software engineering  ,  data structures  ,  multithreading  ,  object oriented programming  ,  big data  ,  mongodb  ,  python  ,  problem solving  ,  algorithm development  ,  nosql',
#        'data entry  ,  MS OFFICE  ,  INVENTORY MANAGEMENT  ,  inbound PROCESS  ,  OUTBOUND PROCESS',
#        'Data Research   ,   Data Processing   ,   Internet Research   ,   Microsoft Office   ,   English Proficiency   ,  history  ,  science  ,  english',
#        'Informatica IDQ  ,  Informatica Data Quality',
#        'COMPUTER OPERATOR  ,  data entry operator  ,  operator  ,  data entry  ,  office assistant',
#        'SAP MDG  ,  BRF+  ,  Data Modelling  ,  ABAP OO',
#        '12TH PASS  ,  And Marketing  ,  Clients  ,  GRADUATE  ,  Ms Office  ,  computer operator  ,  data entry  ,  data entry operator',
#        'sap ecc  ,   sap data architect  ,   data governance  ,   data management  ,   six sigma   ,  information technology  ,  sql  ,  security  ,  database  ,  written communication  ,  system architecture  ,  infrastructure  ,  leadership skills  ,  service oriented architecture',
#        'Research Assistant  ,  research analyst  ,  analyst  ,  networking  ,  data collection  ,  assistance  ,  research  ,  data management  ,  analytics  ,  Research Development  ,  researching',
#        'data entry operator  ,  office assistant  ,  front office executive  ,  front office  ,  data operator',
#        'FRESHER  ,  trainee  ,  data entry  ,  data entry operator  ,  computer operator  ,  system administrator',
#        'Data Analysis  ,  Content Writing  ,  Editorial skills',
#        'ml   (  machine learning  )     ,   python   ,   aws  /  azure   ,   data scientist   ,   sql   ,  algorithms  ,  bi',
#        'Data Warehousing  ,  Data Analysis  ,  new program launches  ,  SLA  ,  Team Management  ,  crawling  /  web scraping  ,   Data Modeling   ,  ETL development  ,  Java  ,  scala   ,  big data technologies',
#        'BACKENED WORK  ,  COMPUTER OPERATOR  ,  data entry operator  ,  manager  ,  team leader',
#        'big data engineering   ,   java   ,   python   ,   scala   ,   sql   ,  orchestration  ,  storage  ,  apache  ,  postgresql  ,  devops  ,  json  ,  shell scripting  ,  mysql  ,  technical skills  ,  written communication  ,  unix  /  linux  ,  software developer',
#        'Customer Care  ,  Computer Data Entry  ,  data entry operator  ,  clerk  ,  customer service executive  ,  customer care executive  ,  call coordinator',
#        '"Unqork"  ,  "Unqork Developer"  ,  "Configuration"  ,  Data workflow',
#        'big data   ,   java   ,   scala   ,   hadoop   ,   spark   ,   aws   ,  orchestration  ,  information technology  ,  apache  ,  devops  ,  software engineering  ,  shell scripting  ,  mysql  ,  python  ,  oracle  ,  unix  /  linux  ,  hive  ,  docker  ,  security  ,  git  ,  postgresql  ,  senior software developer  ,  json  ,  technical skills  ,  rdbms  ,  written communication  ,  infrastructure'],
#       dtype=object)

# %%
# As we can see that there are many extra spaces between them which makes difficult to read it

# A custom function which can remove extra spaces
def remove_extra_spaces(value):

  split_value= str(value).split(',')
  result=[]
  for i in split_value :
    i=i.strip()
    result.append(i)
  delimiter = ','
  str_result = delimiter.join(result)
  return str_result.strip()

# Appying the remove_extra_spaces function to every row
df['Skills_Required']= df['Skills_Required'].apply(remove_extra_spaces)

# String extra space for each row
df['Skills_Required'].apply(str.strip)

# Printing the unique values for the Skills_Required
df['Skills_Required'].unique()
# Out:
# array(['LLM,"Large language model",Datascience,azure,"data scientist",datascientist',
#        'data science,machine learning,natural language processing,advanced analytics,big data,data mining,sql,hadoop,mongodb,python,sas,cassandra,entry level',
#        'machine learning,natural language processing,data science tools,advanced analytics,generative ai,data mining,sql,hadoop,big data,mongodb,python,sas,cassandra,entry level',
#        'data science,digital manufacturing,ml  /  ai  /  dl,data visualization,database skills,information technology,java,big data,python,algorithms,pattern recognition,team player,machine learning,consultant',
#        'python,sas,sql,data extraction,hadoop',
#        'python,rdbms,data mining,machine learning,sql,senior software developer,software developer',
#        'fundamentals,algorithms,python,machine learning,debugging,big data',
#        'Data Science Analyst,Data Science,test model quality,product development,marketing techniques,customer experiences,revenue generation,ad targeting',
#        'python,restful apis,machine learning,html5,javascript,senior software engineer,git',
#        'python developer,python programming', 'Data science',
#        'Data Science,Machine Learning,SQL,NoSQL,Python  /   Spark  /   R Data Science Stack',
#        'machine learning,docker,data science',
#        'TDD,Deep Learnig,Deployment,Mongo DB,SQL,Python,Data Analyst,business analyst,Tableau,Spss,Data Analysis,Data Cleaning,Statistical Analysis,Data Validation,MIS',
#        'chat support,Email Support,Chat Process,Non Voice,Bpo,Customer Care,Back Office,Live Chat,Web Chat,Customer Service,Email,Customer Care Representative',
#        '12TH PASSCOMPUTER OPERATORDATA ENTRYHOME BASED WORKFREELANCERFRESHERSGRADUATE',
#        'spss,data warehousing,sql,data science,data visualization,advanced analytics,solution architect,sas,tableau,project delivery',
#        'Freelancer,part time,Work From Home,Data Entry Operator,Back Office Support,CHAT SUPPORT,Email Support,Chat Process,Email,Live Chat,Customer Support,Ms Office',
#        '12th pass,home based,back office,back office executive,customer support executive,csr',
#        'Computer Operator,data entry operator,Typing,Ms Office,Touch Typing,Erp,Operation,Data,Internet,Word,Microsoft,Back Office,mis executive,backend executive,WPM',
#        'data mining,anova,spss,data science,use cases,data scientist,arima,data analytics,sas,written communication',
#        'data science,machine learning,statistics,python,r,information technology,data mining,sql,cloud services',
#        'data science,machine learning,statistical analysis,data visualization,python coding,data analysis,dashboards,tableau,data scientist',
#        'computer operator,data entry,Ticketing,Cabin crew,HR,Iti Electrician,Hospitality Tourism,Ground staff,customer services,Back office,team leader,IT Operations',
#        'visualization,bi,dashboards,sql,data science,data visualization,advanced analytics,data analytics,analyst',
#        'spss,data science,data analytics,data analysis,tableau,consultant',
#        'data scientist,data science,senior data scientist,java,r,nlp,Data Modeling,ExtJS,Spark,Python',
#        'Data Entry Operator,Data Entry,Computer Operator,Computer Data Entry,Data Entry   /  Computer Operator,Work From Home,Work from Home data Entry,Online Data Entry',
#        'data science,machine learning,statistical analysis,python  &  r,software engineering,devops,software testing,ensemble,security,pattern recognition,natural language processing',
#        'data science,python,spark,sql,aws,fundamentals,git,debugging,software engineering,machine learning,written communication,production environment,unix',
#        'data science,machine learning,ai and analytics,python programming,client engagement,algorithms,data mining,artificial intelligence,sql,it management,san,nosql',
#        'Airport Handling Operation Ground Handling,Armed Security Officer,Fire Safety,Admin Manager,Computer Operator,data entry,data entry operator,operator',
#        '12TH PASS,FRELANCER,FRESHER,Computer Operator,data entry,team leader,Ms Office',
#        'data analysis,data science,sql,python,machine learning,games,messaging,hadoop,san',
#        'FRESHER,trainee,customer service,customer service executive,supervisor,computer supervisor,Data Entry Operator',
#        'computer operator,data entry operator,operator,executive,mis executive,backend executive',
#        '12TH PASS,FRELANCER,FRESHER,Computer Operator,data entry,team leader',
#        'data mining,sql,team player',
#        'Payroll,Management,Store incharge,Store Keeper,Supervisor,Data Entry,Guard,Airport,Airlines,Passport Checker,Ticketing,Ground Staaf,Airport Jobs',
#        'data mining,sql,data visualization,data analysis,pricing models,tableau,analyst',
#        'ground staff,computer operator,data entry,passport,Inspection,bpo,Back-office Operations,Customer Care,Admin And Hr,Non Voice,Operations,Supply Chain,Kpo',
#        'Ground staff,computer operator,data entry,Ticketing,Airlines,Cabin crew,Hospitality Tourism,Security,Hr,Human Resourcs,Back office,team leader,Airport,BPO',
#        'Electrical Mechanical Maintenance,electronics,Telecommunications,Data Communication,Electrical Maintenance,power,Electrical,Auto Cad,Electrical Power System',
#        'Healthcare,Healthcare Management,Hospital Administration,Operations,Claims,provider data management,Customer Success,Client Servicing,client servicing executive',
#        'PECI,PICOF,Workday',
#        'React,Shopify,Git,ROR,Shopify Liquid,Javascript,Node,Python',
#        'Ground staffDomestic TicketingAirline TicketingReservationsTicketingCabin crewBack Office Operationscomputer operatorHospitality Tourism',
#        'Microsoft Identity,IDM domain,ITIL,ITIL v4,L3 technical,Active Directory,MIMWAL,PowerShell,Microsoft SQL',
#        'branch manager,branch incharge,branch head,insurance sales,Life Insurance,General Insurance,Health Insurance,Sales Manager,territory sales manager,DIRECT SALES,',
#        '"SaaS Technica","Fusion Technical","Cloud Technical"',
#        '"Fusion HCM","SaaS HCM","Cloud HCM","Solution Architect","Architect"',
#        '"Oracle Learning Cloud","Fusion HCM","SaaS HCM","Cloud HCM","OLC"',
#        '"Oracle Recruitment Cloud","ORC"',
#        '"Fusion HCM","SaaS HCM","Cloud HCM"',
#        '"Cloud Projects portfolio Management","SaaS Projects portfolio Management","Fusion Projects portfolio Management"',
#        '"SaaS OTM","Cloud OTM","SaaS GTM","Fusion GTM","Cloud GTM","Cloud Global Transportation Management","Global Transportation Management","Fusion OTM"',
#        '"SaaS Technical","Fusion Technical","Cloud Technical",Cloud Computing',
#        'Oracle Production Support,Payment,Banking',
#        '"PSFT Admin","PSFT DBA","PeopleSoft Admin","PeopleSoft DBA","Integration Broker",IB,Upgradetion',
#        'Communication skills,Creative skills,Computer skills,Teamwork skills,Problem-solving skills',
#        'java,react,javasc,css,html,angular,php,jquery,c#,Mean Stack,Mern Stack,Full Stack,LAMP,Lamp Stack,python,Python Scripting,Sql,Saas,AWS,Azure,GCP,Oracle',
#        'full stack,java,Html,css,.net,javascript,php,Database,sql,oracle,reactjs,angularjs,Bootstrap,c#,asp.net,nodejs,Mongodb,Python',
#        'IT',
#        'html,css,Xml,php,angular,react,java,javascript,Dhtml,Sql,Core Java  XML,c ++',
#        'data analytics,data visualization,business intelligence,statistical  /  ml techniques,team management,san,advanced analytics,spotfire,bi,data analyst,tableau,data science,client interaction,sql database',
#        'Clinical Trial,Clinical Research,Pharmacovigilance,Clinical Data Management,Clinical Research Associate,Regulatory Affairs,Uv,Hplc,Calibration,Biotechnology,Dna',
#        'Human Resource Management,Recruitment,hr executive,hr recruiter,MBA,Hr Operations,Hr Generalist,IT recruiter,Hr Assistance,Hr Administration,Hr Admin,Payroll,Hr',
#        'Waterfall,Scrum,Agile Methodologies,Software Project Management,Hybrid,Kanban,MicrosoftTechnology Stack,Big Data,Analytics,Scope,Project',
#        'Azure Analysis Services,Amazon Aws,Devops,Jenkins,Power Bi Desktop,Power Query,Power Bi,Business Analysis,Dax Queries,Sql,Spss,Statistics,Business Intelligence',
#        'hazardous materials handling,lithium ion batteries,materials analysis,microscopy and sem,data analysis and reporting,problem solving,technical skills',
#        'business administration,computer science,data science,product management,agile methodologies,writing,jira',
#        'Information Systems,Computer Science,Computer Engineering,Software Engineering',
#        'Analytical studies,sparkSQL,Data scientist,Artificial Intelligence',
#        'business requirements,information technology,bi,data warehousing,dashboards,data science,business analysis,tableau',
#        'product management,customer experience,market share,data science,communication skills,product development,innovation,ideas,license,spm',
#        'product management,business administration,technical background,agile methodologies,data science,writing,jira,validation testing',
#        'product analytics,data science,r,sql,python,marketing campaigns,marketing analytics,digital analytics,marketing initiatives',
#        'python,data science,ai,cloud,cyber security,reports,information technology,cms,content management',
#        'c,spss,java,data science,client facing,advanced analytics,genesys,sas,business analytics,analyst',
#        'healthcare pharma  /  claims,data analysis,life sciences,statistical research,sas programming,security,data scientist,data analyst,statistical analysis',
#        'Testing,Qa,Qc,Automation Testing,Selenium,Jira,Core Java,Manual Tester,test engineer,qa engineer,qa lead,it analyst,Trainee,Software Quality Testing,Bug,linux',
#        'business requirements,business analyst,sql,process mapping,data science,brd,data analysis,requirement elicitation,written communication,visio',
#        'data science,business consulting,analytics,ai,dataops,technology consulting,cpg,san,customer analytics,data analysis,predictive analytics',
#        'Data scientist', 'snowflakes',
#        'data entry,data management,MS OFFICE,Warehousing,inventory management',
#        'computer skills', 'Data quality',
#        'machine learning,data science,software development,numerical analysis,regression analysis,c,sql,security,git,devops,python,natural language processing',
#        'user experience design,product design,ux research,data science,engineering,typography,composition,ux design,mobile,articulate,motion graphics,designing',
#        'reservoir engineering,analytical skills,reservoir simulation,data science,fluid mechanics,python,ipm,eclipse,storage,security,machine learning',
#        'visualization,dashboards,text analytics,logistic regression,advanced analytics,data analytics,data mining,bi,sql,database,data science,product analyst,data visualization,cluster analysis,crm,san,data analysis,tableau',
#        'data analytics,business insights,data analysis,visualization tools,communication skills,bi,sql,database,data science,use cases,lead analyst,predictive analytics,data analyst,tableau,consultant,infrastructure',
#        'data analytics,data visualization,business intelligence,problem solving,project management,san,advanced analytics,bi,dashboards,tableau,data science,client interaction,sql database',
#        'Agile,UML,Web Technologies,Java,Cloud,java,uml,j2ee,problem solving,hl7,web technologies,software developer',
#        'Azure',
#        'data analysis,python,excel,data visualization,sql,bi,data extraction,database,git,technical skills,machine learning,infrastructure,data communication',
#        'algorithms,python,apache', 'algorithms,python,sas,sql',
#        'hive,fundamentals,algorithms,information technology,data mining,bi,sql,data extraction,atg,mongodb,python,rdbms,machine learning,nosql,cassandra,infrastructure',
#        'algorithms,c,data mining,sql,python',
#        'algorithms,python,data mining,sql,data structures,big data',
#        'data analysis,analytics,python,power bi,visualization,hive,data extraction,api,oracle,sas,microsoft azure',
#        'data engineering,etl,informatica cloud,machine learning,python,salesforce,shell scripting,github,oracle,director,algorithms,bi,sql,entry level,forms',
#        'data engineering,sql databases,python automation,cloud services   (  aws  ),etl processes,jam,games,simulator,mobile,infrastructure',
#        'data engineering,sql databases,python automation,cloud services,etl processes,artificial intelligence,jam,games,simulator,mobile,infrastructure',
#        '1  )   data stewardship 2  )   data strategy 3  )   data governance 4  )   data management 5  )   analytics capabilities,information technology,salesforce,python,data mining,sql,database,sem,crm,team player',
#        'algorithms,information technology,data warehousing,storage,sql,security,java,hadoop,big data,python,nosql,infrastructure',
#        'data mining,sql,data scientist,predictive analysis,advanced analytics,data analysis,sas,author,predictive analytics,algorithm development,statistical analysis',
#        'python,c,scala,oozie,sql,nosql,java,cassandra,hadoop,big data',
#        'storage,database,adf,python,cl,sql scripting,sql database',
#        'information technology,team player,sql',
#        'scala,bi,sql,security,java,devops,technical skills,python,machine learning,infrastructure',
#        'data systems architecture,data systems engineering,software engineering,site reliability engineering,data management,c,orchestration,mysql,python,nosql,cassandra,openstack,docker,security,mongodb,infrastructure',
#        'Scrum Master,Manufacturing and Automation,Data Analytics',
#        'Data Modeling', 'Data Modeling,data assessment',
#        'Data Analyst,analyst,senior analyst,system analyst',
#        'OBIEE,,SQL,Business Intelligence Data Warehousing',
#        'support engineer,data centre,power cycling,Rebooting,Inventory management,network connectivity,BOM verification,DCIM tool,Amber LED,Cable Dressing,Infra Power',
#        'Data Engineer',
#        'Typing skills,Ms Office,ms word,40 wpm,Data Entry,computer operator',
#        'azure,python,pyspark', 'Azure,Data engineer',
#        'Data ingestion,ETL,Data Warehousing,CDC,Data Modeling,Data Engineering',
#        'Business Analysis,big data,Agile Programming,Scaled agile framework',
#        'Basic Computer Skills,computer operator,office assistant',
#        'ODI,"Oracle Data Integrator","Data warehousing",DWH',
#        'algorithms,python,machine learning,sql,d3.js,data structures,mongodb',
#        'learning acumen,team management,problem solver,data interpretation,machine learning,algorithms,information technology,data extraction,java,linux,big data,san,python',
#        'Data ingestion,Databricks,Datawarehouse,Data Modeling,Developing pipelines,Azure Cloud Services',
#        'algorithms,ds,sql,big data,python,machine learning',
#        'java,python,spark,sql,aws,fundamentals,git,debugging,software engineering,big data,machine learning,written communication,production environment,unix',
#        'algorithms,python,machine learning,sql,d3.js,mongodb',
#        'hive,algorithms,data mining,sql,pig,mongodb,hbase,simulation models,python,machine learning,nosql,cassandra',
#        'bi,data warehousing,data architecture,data marts,sql,data transformation,etl,data architect,data quality',
#        'sql,cloud computing,python,machine learning',
#        'software development,big data,cloud implementation,sql,agile scrum,orchestration,scala,storage,security,java,apache,postgresql,devops,json,shell scripting,mysql,technical skills,python,written communication,unix  /  linux,software developer',
#        'big data,apache spark,cloud implementation,resilience,agile scrum,orchestration,information technology,java,software engineering,shell scripting,mysql,python,oracle,unix  /  linux,hive,scala,docker,security,git,postgresql,json,hadoop,technical skills,rdbms,written communication',
#        'Java,Scala,Python,MYSQL,MS SQL,NOSQL,Columnar Databases,Spark Streaming,Apache Kafka,design algorithms,predictive analytics,tenacity',
#        'quantitative analytics,risk assessment,fraud detection,underwriting,machine learning,bi,sql,python',
#        'data architecture,azure cloud services,agile environment,data modelling,data integration patterns,etl,data profiling,data engineer,data quality,data warehousing,crm,solution architect,infrastructure,sql database',
#        'Data Entry,Data Entry Operator,Work From Home,Home base work,Work From Home Data Entry,Computer Operator,Data Entry Computer Operator,Home base job',
#        'data engineering,aws,etl scripting,data warehousing,sql,python,data mining,node.js,database,big data',
#        'algorithms,python,informationtechnology,team player,machine learning,data extraction,java,linux,big data',
#        'data engineering,sql,nosql,cloud services,container technologies,docker,database,git,couchbase,mysql,big data,technical skills,mongodb,oracle',
#        'algorithms,artificial intelligence,sql,data extraction,big data,python,natural language processing,team player,machine learning,nosql',
#        'data services,cloud native dbaas,relational databases,nosql,communication skills,technical leader,information technology,security,rdbms,infrastructure',
#        'machine learning,search,pattern recognition,text mining,big data,conference,data mining',
#        'data engineering,etl solutions,python,sql,spark,hive,algorithms,storage,pig,apache,git,data structures,dash',
#        'information technology,sql,database management,security,database,technology management,postgresql,linux,mysql,pl  /  sql,big data,mongodb,cloud services,oracle,microsoft azure,production environment',
#        'machine learning,artificial intelligence,docker',
#        'css,python,c,jquery,javascript,web development,html',
#        'linux operating system,sql scripting,database,php,mysql,unix',
#        'fundamentals,sql,database,python scripting,git,devops,software engineering,python,rdbms',
#        'aws  /  gcp,ec2,iam,s3,docker,kubernetes,jenkins,prometheus,python,golang,shell scripting,networking,relational databases,non relational databases.,fundamentals,devops',
#        'ADF,Synapse,Azure data factory',
#        'Back Office Server,accounts,Financial Accounting,Ms Office,system administrator,desktop support,customer support engineer,Collection Process',
#        'Google Big Query',
#        'Python Developer,Java Developer,software developer,Network Engineer,system engineer,system administrator,it executive',
#        'NUTRITION,Food Processing,Food Processing Industry,Food Science,Food Analysis,Microbiology,Clinical Nutrition,Diet Planning,Nutritionist,Dietitian',
#        'Email,CHAT SUPPORT,Email Support,Chat Process,Non Voice,Kpo,Bpo,Live Chat,Back Office,Web Chat,AIR TICKETING,International Ticketing,Amadeus,Ticket Booking',
#        'Typing Skill,Communication skills,MS Office',
#        'data analysis,sql,python programming,machine learning,communication skills,games,messaging,hadoop,san',
#        'algorithms,python,rdbms,nosql,written communication,data structures,hadoop,big data',
#        'big data administration,team management,hadoop administration,database management,cloud services,messaging,mapreduce,unix  /  linux,hive,cloudera,data warehousing,storage,sql,security,technical skills,oozie,hdfs',
#        'data analysis,python,excel,sql,communication,bi,data extraction,database,git,technical skills,machine learning,infrastructure,data communication',
#        'medical writing,clinical research,regulatory affairs,clinical data management,clinical sas,pharma,pharmacovigilance',
#        'data engineering,data warehousing,etl  /  elt processes,python,jenkins ci  /  cd,business rules,devops,software engineering,api,erp  /  crm,nosql,software design,bi,security,data extraction,git,information management,software delivery,mobile,infrastructure',
#        'data engineering,information security,etl  /  elt processes,ci  /  cd platform   (  jenkins  ),python  /  powershell,business rules,devops,software engineering,api,erp  /  crm,nosql,software design,bi,data warehousing,data extraction,git,information management,software delivery,mobile,infrastructure',
#        'databricks,pyspark,sql,microsoft azure,data engineering,orchestration,bi,storage,python,machine learning',
#        '12TH,GRADUATE.,BA,B.com,10TH,WORK FROM HOME,PART TIME,Full Time,Time Management,Good Communication',
#        'Ms-office,12TH PASS,GRADUATE,Fresher,trainee,customer service,team leader,system administrator',
#        'SAP MDG',
#        'Teamwork,Problem - Solving,Written Communication,Leadership',
#        'FRESHER,ADMINISTARTION,12TH PASS,COMPUTER OPERATOR,operator,data entry',
#        'FRESHER,ADMINISTRATION,Computer Operator,office assistant,assistant,executive assistant',
#        '12th PASS OUT,FRESHERS,COMPUTER   /    SKILLS,GRADUATE',
#        'SQL,IBM Cognos,Spotfire,Knowledge of Scripting   (  XML,Java Script,Shell Scripting,Perl etc  )',
#        'Manufacturing and Automation,IoT - General Experience,Cloud development,Microservices architecture   (  MSA  ),.net Core',
#        'Biology Teacher,Science Teacher,Maths Teacher,Teaching,Teacher',
#        'SAP,SAPSD,MASTER DATA MANAGEMENT',
#        'Data Entry,Back Office,Computer Operator',
#        'machine learning,mathematical skills,problem solving,coding,data visualization,data mining,storage,sql,database,big data,python,cloud services,information management,forms',
#        'bigquery,data studio,data infrastructure management,data analysis and visualization,data integration and etl,data warehousing,storage,sql,security,data extraction,data services,data quality',
#        'ERP Data Migration,SAP Data Migration,PLM Data Migration,MDM,Oracle ERP Data Migration,functional analyst,data migration,pmp,oracle erp,crm,master data,sap,solution architect,workflow,implementation,written communication,mdm,mediator',
#        'airflow,python,spark,sql,nosql,docker,database,git,couchbase,mysql,big data,technical skills,mongodb,oracle',
#        'airflow,python,spark,database systems,cloud service technologies,sql,docker,git,couchbase,mysql,big data,technical skills,mongodb,oracle,nosql',
#        'Java,Python,Scala,Big Data,Software Development,algorithms,information technology,scala,java,oops,software engineer,software engineering,data structures,multithreading,object oriented programming,big data,mongodb,python,problem solving,algorithm development,nosql',
#        'data entry,MS OFFICE,INVENTORY MANAGEMENT,inbound PROCESS,OUTBOUND PROCESS',
#        'Data Research,Data Processing,Internet Research,Microsoft Office,English Proficiency,history,science,english',
#        'Informatica IDQ,Informatica Data Quality',
#        'COMPUTER OPERATOR,data entry operator,operator,data entry,office assistant',
#        'SAP MDG,BRF+,Data Modelling,ABAP OO',
#        '12TH PASS,And Marketing,Clients,GRADUATE,Ms Office,computer operator,data entry,data entry operator',
#        'sap ecc,sap data architect,data governance,data management,six sigma,information technology,sql,security,database,written communication,system architecture,infrastructure,leadership skills,service oriented architecture',
#        'Research Assistant,research analyst,analyst,networking,data collection,assistance,research,data management,analytics,Research Development,researching',
#        'data entry operator,office assistant,front office executive,front office,data operator',
#        'FRESHER,trainee,data entry,data entry operator,computer operator,system administrator',
#        'Data Analysis,Content Writing,Editorial skills',
#        'ml   (  machine learning  ),python,aws  /  azure,data scientist,sql,algorithms,bi',
#        'Data Warehousing,Data Analysis,new program launches,SLA,Team Management,crawling  /  web scraping,Data Modeling,ETL development,Java,scala,big data technologies',
#        'BACKENED WORK,COMPUTER OPERATOR,data entry operator,manager,team leader',
#        'big data engineering,java,python,scala,sql,orchestration,storage,apache,postgresql,devops,json,shell scripting,mysql,technical skills,written communication,unix  /  linux,software developer',
#        'Customer Care,Computer Data Entry,data entry operator,clerk,customer service executive,customer care executive,call coordinator',
#        '"Unqork","Unqork Developer","Configuration",Data workflow',
#        'big data,java,scala,hadoop,spark,aws,orchestration,information technology,apache,devops,software engineering,shell scripting,mysql,python,oracle,unix  /  linux,hive,docker,security,git,postgresql,senior software developer,json,technical skills,rdbms,written communication,infrastructure'],
#       dtype=object)

# %%
# Printing the unique values for the Job_Publish_Date
df['Job_Publish_Date'].unique()
# Out:
# array(['3 days ago', '6 days ago', 'few days ago', 'a month ago', 'today',
#        '2 days ago', 'Work from Home     1 day ago', '1 day ago',
#        'Work from Home     2 days ago', '5 days ago', '4 days ago',
#        'Work from Home     a month ago',
#        'Work from Home     few days ago', 'Work from Home     3 days ago'],
#       dtype=object)

# %%
# As we can see that the Job_Publish_Date is in object datatype therefore we will convert it into int datatype

# Mapping dictionary for non-standard date strings to standardized format
date_mapping = {
    'few days ago': '2 days ago',
    'a month ago': '30 days ago',
    'today': '0 days ago',
    'Work from Home': '',  # Remove 'Work from Home' text
}

# Clean the 'Job_Publish_Date' column using the mapping dictionary
df['Job_Published_Days_ago'] = df['Job_Publish_Date'].replace(date_mapping, regex=True)

# Extract numerical days from the cleaned 'Job_Publish_Date' column
df['Job_Published_Days_ago'] = df['Job_Published_Days_ago'].str.extract('(\d+)').astype(float)

# Droping the Job_Publish_Date column
df.drop(['Job_Publish_Date'],axis=1, inplace=True)

# Print unique values in the cleaned 'Job_Published_Days_ago' column
print(df['Job_Published_Days_ago'].unique())
# Out:
# [ 3.  6.  2. 30.  0.  1.  5.  4.]

# %%
# Printing the unique values for the mix
df['mix'].unique()
# Out:
# array(['card_travel7 - 12 yrs\n₹Rs 15.00 - 35.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune',
#        'card_travel3 - 5 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel9 - 12 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel3 - 6 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel20 - 23 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel2 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai',
#        'card_travel2 - 5 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel4 - 6 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 8 yrs\n₹Rs 15.00 - 32.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Gurgaon,  Hyderabad/Secunderabad,  Mumbai',
#        'card_travel0 - 3 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 1 yrs\n₹Rs 4.50 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Pune,  Cochin/ Kochi/ Ernakulam',
#        'card_travel0 - 3 yrs\n₹Rs 1.80 - 3.40 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Chandigarh',
#        'card_travel1 - 6 yrs\n₹Rs 3.05 - 8.10 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Kolkata,  Mumbai,  Pune',
#        'card_travel0 - 1 yrs\n₹Rs 2.95 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Patna',
#        'card_travel1 - 6 yrs\n₹Rs 2.70 - 5.10 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Panjim/Panaji,  Vasco Da Gama',
#        'card_travel0 - 3 yrs\n₹Rs 4.50 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Pune,  Cochin/ Kochi/ Ernakulam',
#        'card_travel5 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 2 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 5.20 - 10.25 Lacs p.a.\n\nlocation_on\nBelgaum,  Bengaluru / Bangalore,  Bidar,  Dharwad,  Gulbarga',
#        'card_travel2 - 5 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Kolkata,  Pune,  Bengaluru / Bangalore',
#        'card_travel5 - 10 yrs\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Gurgaon',
#        'card_travel0 - 3 yrs\n₹Rs 1.25 - 2.20 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Delhi,  Hyderabad/Secunderabad,  Mumbai,  Surat',
#        'card_travel1 - 2 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel10 - 13 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 1.50 - 3.70 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai,  Pune',
#        'card_travel1 - 5 yrs\n₹Rs 2.35 - 3.20 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Mahabaleshwar',
#        'card_travel7 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 6 yrs\n₹Rs 2.15 - 5.30 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Coimbatore',
#        'card_travel1 - 5 yrs\n₹Rs 2.15 - 3.20 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Mumbai,  Pune',
#        'card_travel1 - 5 yrs\n₹Rs 2.25 - 6.10 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Vasco Da Gama,  Bhubaneshwar,  Mathura',
#        'card_travel1 - 5 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 1.40 - 7.35 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Bidar,  Davanagere,  Dharwad,  Gulbarga',
#        'card_travel0 - 1 yrs\n₹Rs 2.50 - 4.40 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Mumbai,  Chandigarh,  Kurnool',
#        'card_travel0 - 1 yrs\n₹Rs 1.95 - 3.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Patna',
#        'card_travel0 - 2 yrs\n₹Rs 5.05 - 10.15 Lacs p.a.\n\nlocation_on\nBelgaum,  Bengaluru / Bangalore,  Bidar,  Gulbarga,  Hubli',
#        'card_travel0 - 2 yrs\n₹Rs 5.05 - 10.15 Lacs p.a.\n\nlocation_on\nBelgaum,  Bengaluru / Bangalore,  Davanagere,  Dharwad,  Gulbarga',
#        'card_travel2 - 7 yrs\n₹Rs 9.00 - 60.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Mumbai,  Australia,  Canada',
#        'card_travel0 - 3 yrs\n₹Rs 5.30 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Pune,  Cochin/ Kochi/ Ernakulam',
#        'card_travel5 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Mumbai,  Noida/Greater Noida,  Pune',
#        'card_travel3 - 5 yrs\n₹Rs 9.00 - 12.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Delhi,  Gurgaon,  Mumbai,  Pune',
#        'card_travel0 - 3 yrs\n₹Rs 2.15 - 5.10 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi,  Hyderabad/Secunderabad,  Mumbai',
#        'card_travel2 - 7 yrs\n₹Rs 1.00 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel4 - 9 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Kolkata,  Mumbai,  Pune',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Kolkata,  Mumbai,  Pune',
#        'card_travel6 - 11 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Kolkata,  Mumbai,  Pune',
#        'card_travel5 - 10 yrs\n₹Rs 9.00 - 27.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai',
#        'card_travel3 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Kolkata,  Mumbai,  Pune',
#        'card_travel0 - 3 yrs\n₹Rs 6.00 - 12.00 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR',
#        'card_travel4 - 9 yrs\n₹Rs 20.00 - 70.00 Lacs p.a.\n\nlocation_on\nKolkata,  Mumbai,  Vijayawada,  Bengaluru / Bangalore',
#        'card_travel6 - 11 yrs\n₹Rs 10.00 - 61.00 Lacs p.a.\n\nlocation_on\nPune,  Hyderabad/Secunderabad,  Rajkot,  Bengaluru / Bangalore,  Bhubaneshwar',
#        'card_travel0 - 1 yrs\n₹Rs 1.10 - 2.40 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel3 - 8 yrs\n₹Rs 10.00 - 63.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Australia,  Canada',
#        'card_travel0 - 1 yrs\n₹Rs 5.30 - 7.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Pune,  Cochin/ Kochi/ Ernakulam',
#        'card_travel2 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel2 - 5 yrs\n\nlocation_on\nDelhi,  Delhi/NCR,  Bengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 1.20 - 4.80 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Gurgaon,  Chandigarh,  Bhubaneshwar',
#        'card_travel3 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel4 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel2 - 3 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel3 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore,  Gurgaon',
#        'card_travel5 - 8 yrs\n\nlocation_on\nDelhi,  Delhi/NCR,  Bengaluru / Bangalore',
#        'card_travel6 - 9 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel6 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 2 yrs\n₹Rs 1.10 - 3.25 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 1 yrs\n₹Rs 2.00 - 2.40 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel8 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Kolkata,  Mumbai',
#        'card_travel4 - 6 yrs\n\nlocation_on\nMumbai,  Bengaluru / Bangalore,  Gurgaon',
#        'card_travel3 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel8 - 11 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel8 - 12 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 12 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel4 - 9 yrs\n₹Rs 10.00 - 27.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel8 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 8 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Mumbai,  Bengaluru / Bangalore',
#        'card_travel2 - 5 yrs\n\nlocation_on\nChennai,  Bengaluru / Bangalore,  Hyderabad/Secunderabad,  Other City(s) in Karnataka',
#        'card_travel3 - 5 yrs\n\nlocation_on\nMumbai,  Bengaluru / Bangalore',
#        'card_travel3 - 6 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Bengaluru / Bangalore',
#        'card_travel6 - 9 yrs\n\nlocation_on\nDelhi,  Delhi/NCR,  Bengaluru / Bangalore',
#        'card_travel13 - 15 yrs\n₹Rs 15.00 - 32.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Gurgaon,  Mumbai,  Noida/Greater Noida',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune',
#        'card_travel4 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Kolkata,  Mumbai',
#        'card_travel3 - 7 yrs\n₹Rs 6.00 - 99.90 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Gurgaon',
#        'card_travel1 - 6 yrs\n₹Rs 2.50 - 3.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 1 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Pune,  Nizamabad,  Visakhapatnam',
#        'card_travel5 - 9 yrs\n\nlocation_on\nBengaluru / Bangalore,  Delhi/NCR,  Mumbai',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Mumbai',
#        'card_travel8 - 13 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR',
#        'card_travel7 - 12 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai',
#        'card_travel0 - 3 yrs\n₹Rs 2.50 - 3.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Gurgaon',
#        'card_travel3 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore,  Hyderabad/Secunderabad,  Kolkata,  Mumbai,  Noida/Greater Noida',
#        'card_travel10 - 15 yrs\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad',
#        'card_travel10 - 13 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Bengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n\nlocation_on\nGurgaon,  Mumbai,  Pune,  Bengaluru / Bangalore',
#        'card_travel5 - 8 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Bengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 1.20 - 2.30 Lacs p.a.\n\nlocation_on\nDelhi,  Hyderabad/Secunderabad,  Bengaluru / Bangalore,  Mumbai,  Chennai',
#        'card_travel0 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 3 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel3 - 4 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel12 - 18 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel17 - 20 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Chennai,  Pune,  Bengaluru / Bangalore',
#        'card_travel6 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel7 - 12 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad',
#        'card_travel0 - 1 yrs\n₹Rs 2.00 - 5.00 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Kolkata,  Mumbai,  Guwahati',
#        'card_travel5 - 9 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 4.30 - 6.80 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Rajahmundry,  Vijayawada',
#        'card_travel5 - 10 yrs\n₹Rs 1.00 - 50.00 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Gurgaon',
#        'card_travel1 - 6 yrs\n₹Rs 2.15 - 4.10 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Mumbai',
#        'card_travel0 - 1 yrs\n₹Rs 2.40 - 6.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Delhi,  Pune,  Shillong,  Amritsar',
#        'card_travel1 - 5 yrs\n₹Rs 2.20 - 4.15 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Patna,  Porbandar',
#        'card_travel0 - 3 yrs\n₹Rs 1.40 - 7.35 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR',
#        'card_travel0 - 3 yrs\n₹Rs 2.50 - 3.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Gurgaon',
#        'card_travel2 - 5 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Pune,  Bengaluru / Bangalore',
#        'card_travel4 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n\nlocation_on\nHyderabad/Secunderabad,  Chennai,  Vijayawada,  Bengaluru / Bangalore',
#        'card_travel4 - 7 yrs\n\nlocation_on\nBengaluru / Bangalore,  Gurgaon',
#        'card_travel1 - 6 yrs\n₹Rs 2.15 - 5.10 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Guntakal,  Mahabubnagar,  Patna',
#        'card_travel1 - 6 yrs\n₹Rs 2.20 - 4.10 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Lakshdweep,  Pondicherry/Puducherry',
#        'card_travel4 - 9 yrs\n₹Rs 10.00 - 25.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 5 yrs\n₹Rs 2.10 - 5.10 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chandigarh,  Karimnagar,  Ongole,  Itanagar',
#        'card_travel1 - 6 yrs\n₹Rs 2.10 - 6.15 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Karimnagar,  Porbandar',
#        'card_travel0 - 3 yrs\n₹Rs 7.00 - 10.00 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Delhi,  Delhi/NCR',
#        'card_travel1 - 5 yrs\n₹Rs 2.20 - 5.20 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Kolkata,  Vasco Da Gama,  Rajkot,  Kolar',
#        'card_travel1 - 5 yrs\n₹Rs 2.35 - 4.20 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Chandigarh,  Daman & Diu,  Lakshdweep',
#        'card_travel1 - 5 yrs\n₹Rs 2.15 - 5.10 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Nellore,  Vellore',
#        'card_travel2 - 7 yrs\n₹Rs 2.00 - 4.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel13 - 15 yrs\n₹Rs 20.00 - 42.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Gurgaon,  Mumbai,  Noida/Greater Noida',
#        'card_travel5 - 10 yrs\n₹Rs 5.00 - 30.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune',
#        'card_travel6 - 7 yrs\n₹Rs 7.00 - 12.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 3 yrs\n₹Rs 2.50 - 6.50 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad',
#        'card_travel3 - 4 yrs\n\nlocation_on\nBengaluru / Bangalore,  Pune',
#        'card_travel16 - 22 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel2 - 6 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel0 - 1 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel5 - 10 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Kolkata',
#        'card_travel1 - 6 yrs\n₹Rs 2.70 - 5.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Chandigarh,  Daman & Diu,  Visakhapatnam',
#        'card_travel6 - 11 yrs\n₹Rs 18.00 - 20.00 Lacs p.a.\n\nlocation_on\nHyderabad/Secunderabad,  Bengaluru / Bangalore,  Mumbai,  Pune,  Chennai',
#        'card_travel1 - 5 yrs\n₹Rs 2.40 - 4.05 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Pune',
#        'card_travel1 - 5 yrs\n₹Rs 2.40 - 4.05 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Rajkot',
#        'card_travel10 - 18 yrs\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 5 yrs\n₹Rs 2.40 - 4.05 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Ujjain',
#        'card_travel6 - 11 yrs\n₹Rs 6.00 - 80.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore',
#        'card_travel1 - 5 yrs\n₹Rs 2.15 - 4.15 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Mumbai',
#        'card_travel1 - 5 yrs\n₹Rs 2.20 - 3.15 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Pune,  Andaman & Nicobar,  Chandigarh',
#        'card_travel1 - 5 yrs\n₹Rs 2.40 - 4.05 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Kolkata,  Bhiwani',
#        'card_travel1 - 3 yrs\n₹Rs 3.00 - 5.00 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Gurgaon',
#        'card_travel4 - 7 yrs\n\nlocation_on\nMumbai,  Bengaluru / Bangalore,  Pune',
#        'card_travel11 - 16 yrs\n\nlocation_on\nBengaluru / Bangalore,  Delhi/NCR,  Hyderabad/Secunderabad,  Kolkata,  Mumbai',
#        'card_travel1 - 5 yrs\n₹Rs 2.20 - 5.20 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Kolkata,  Pondicherry/Puducherry,  Mumbai,  Navi Mumbai',
#        'card_travel0 - 3 yrs\n₹Rs 1.50 - 3.70 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Delhi/NCR,  Hyderabad/Secunderabad,  Mumbai',
#        'card_travel1 - 5 yrs\n₹Rs 2.20 - 5.20 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Kolkata,  Vasco Da Gama,  Mumbai,  Shillong',
#        'card_travel1 - 5 yrs\n₹Rs 2.15 - 4.05 Lacs p.a.\n\nlocation_on\nAhmedabad,  Bengaluru / Bangalore,  Chennai,  Dadra & Nagar Haveli - Silvassa,  Vasco Da Gama',
#        'card_travel1 - 5 yrs\n₹Rs 2.15 - 4.10 Lacs p.a.\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Chandigarh,  Vijayawada,  Panjim/Panaji',
#        'card_travel5 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore,  Chennai,  Hyderabad/Secunderabad,  Mumbai,  Pune',
#        'card_travel4 - 8 yrs\n\nlocation_on\nBengaluru / Bangalore'],
#       dtype=object)

# %%
# Here i am extracting the 3 columns 'Experience', 'Salary', and 'Location' using regular expressions from mix column

# Extracting Experience column
df['Experience'] = df['mix'].str.extract(r'(\d+ - \d+) yrs')


# Extracting the salary column
salary_match = df['mix'].str.extract(r'₹Rs ([\d.]+) - ([\d.]+) Lacs p\.a\.')
df['Salary_Lower'] = salary_match[0].astype(float) * 100000   # Lower limit
df['Salary_Upper'] = salary_match[1].astype(float) * 100000   # Upper limit
df['Salary'] = (df['Salary_Lower'] + df['Salary_Upper']) / 2  # Average salary
df['Salary'].fillna("Unknown", inplace=True)                  # replacing the null values in 'Salary' with "Unknown"

# Extracting Location column
df['Location'] = df['mix'].str.extract(r'location_on\n(.*)$')


# droping the 'Salary_Upper','Salary_Lower' column
df.drop(['Salary_Upper','Salary_Lower','mix'],axis=1, inplace=True)


# Printing the head of dataframe
df.head()
# Out:
#        Company_Name                                    Skills_Required  \
# 0  LTIMindtree Ltd.  LLM,"Large language model",Datascience,azure,"...
# 1       Informatica  data science,machine learning,natural language...
# 2       Informatica  data science,machine learning,natural language...
# 3       Informatica  machine learning,natural language processing,d...
# 4       Informatica  machine learning,natural language processing,d...
#
#                                           Apply_link  Job_Published_Days_ago  \
# 0  https://www.timesjobs.com/job-detail/data-scie...                     3.0
# 1  https://www.timesjobs.com/job-detail/member-da...                     6.0
# 2  https://www.timesjobs.com/job-detail/member-da...                     6.0
# 3  https://www.timesjobs.com/job-detail/member-da...                     6.0
# 4  https://www.timesjobs.com/job-detail/member-da...                     6.0
#
#   Experience     Salary                                           Location
# 0     7 - 12  2500000.0  Bengaluru / Bangalore,  Chennai,  Hyderabad/Se...
# 1      3 - 5    Unknown                              Bengaluru / Bangalore
# 2      3 - 5    Unknown                              Bengaluru / Bangalore
# 3      3 - 5    Unknown                              Bengaluru / Bangalore
# 4      3 - 5    Unknown                              Bengaluru / Bangalore

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (250, 7)

# %%
# Printing the head of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Company_Name            250 non-null    object
#  1   Skills_Required         250 non-null    object
#  2   Apply_link              250 non-null    object
#  3   Job_Published_Days_ago  250 non-null    float64
#  4   Experience              250 non-null    object
#  5   Salary                  250 non-null    object
#  6   Location                250 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 13.8+ KB

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Company_Name              0
# Skills_Required           0
# Apply_link                0
# Job_Published_Days_ago    0
# Experience                0
# Salary                    0
# Location                  0
# dtype: int64

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Company_Name', 'Skills_Required', 'Apply_link',
#        'Job_Published_Days_ago', 'Experience', 'Salary', 'Location'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#               Company_Name                                    Skills_Required  \
# count                  250                                                250
# unique                  92                                                207
# top     SN WEB ENTERPRISES  12TH PASS,And Marketing,Clients,GRADUATE,Ms Of...
# freq                    35                                                  7
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#                                                Apply_link  \
# count                                                 250
# unique                                                250
# top     https://www.timesjobs.com/job-detail/data-scie...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         Job_Published_Days_ago Experience   Salary               Location
# count               250.000000        250      250                    250
# unique                     NaN         49       57                     84
# top                        NaN      1 - 5  Unknown  Bengaluru / Bangalore
# freq                       NaN         30      156                    119
# mean                  7.608000        NaN      NaN                    NaN
# std                  10.772116        NaN      NaN                    NaN
# min                   0.000000        NaN      NaN                    NaN
# 25%                   2.000000        NaN      NaN                    NaN
# 50%                   2.000000        NaN      NaN                    NaN
# 75%                   6.000000        NaN      NaN                    NaN
# max                  30.000000        NaN      NaN                    NaN

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Barplot
# **Purpose:** Show the distribution of job listings among different companies.

# %%
# Count job listings by company
company_counts = df['Company_Name'].value_counts().head(10)

# Plotting
plt.figure(figsize=(16, 8))
company_counts.plot(kind='bar')
plt.xlabel('Company Name')
plt.ylabel('Number of Job Listings')
plt.title('Top 10 Companies with Most Job Listings')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insight:** Identifies companies with the highest number of job listings.
#
# **Implications:** Job seekers can focus their applications on these companies, indicating high recruitment activity.

# %% [markdown]
# #### Chart - 2 Pie chart
# **Purpose:** Display the proportion of job listings based on required experience levels.

# %%
# Count job listings by experience level
experience_counts = df['Experience'].value_counts().head(5)

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(experience_counts, labels=experience_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Job Listings by Experience Level')
plt.show()

# %% [markdown]
# **Insight:** Shows the distribution of job listings based on experience requirements.The experience levels most in demand is 0-3 upto 26.9%.
#
# **Implications:** Helps job seekers understand the experience levels most in demand. Employers can tailor job descriptions based on popular experience levels.

# %% [markdown]
# #### Chart - 3 Box plot
# **Purpose:** Show the distribution of salary ranges.

# %%
# Remove 'Unknown' values
df_ = df[df['Salary'] != 'Unknown']

# Counts the top 5 most frequent salary values from the filtered DataFrame df_.
experience_counts = df_['Salary'].value_counts().head(5)

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(experience_counts, labels=experience_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Job Listings by Salary')
plt.show()

# %% [markdown]
# **Insight:** Shows the distribution of job listings based on salary.The salary levels most in demand is 8.5 LPA upto 24.1%.
#
# **Implications:** Helps job seekers understand the salary levels most in demand. Employers can tailor job descriptions based on popular salary levels.

# %% [markdown]
# #### Chart - 4 Word cloud
# **Purpose:** Visualize the most frequently mentioned skills in job listings.

# %%
from wordcloud import WordCloud

# Combine skills into a single string
skills_text = ' '.join(df['Skills_Required'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(skills_text)

# Plotting
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Mentioned Skills in Job Listings')
plt.show()

# %% [markdown]
# **Insight:** Highlights the most frequently mentioned skills in job listings.
#
# **Implications:** Job seekers can prioritize learning or showcasing these skills. Employers can identify common skills in demand for potential training or recruitment strategies.

# %% [markdown]
# #### Chart - 5 Bar plot
# **Purpose:** Show the distribution of job listings among different locations.

# %%
# Count job listings by Location
company_counts = df['Location'].value_counts().head(5)

# Plotting
plt.figure(figsize=(16, 8))
company_counts.plot(kind='bar')
plt.xlabel('Location')
plt.ylabel('Number of Job Listings')
plt.title('Top 5 Location with Most Job Listings')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insight:** Identifies locations with the highest number of job listings.
#
# **Implications:** Job seekers can focus their applications on these location, indicating high recruitment activity.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# 1. **Web Scraping Data:**
# Objective: Gather data science job listings from timejob online platforms.
# Approach: Utilize Python libraries like BeautifulSoup and requests to scrape job details including company names, skills required, experience levels, salaries, locations, and publish dates from multiple job portals.
# Challenges: Adapt to evolving website structures and handle dynamic content.
# 2. **Data Cleaning and Preparation:**
# Objective: Prepare the scraped data for analysis and visualization.
# Steps: Remove irrelevant information, handle missing or inconsistent data, convert data types, and create a structured DataFrame.
# Challenges: Dealing with 'Unknown' or missing values, standardizing publish date formats, and cleaning salary data.
# 3. **Data Analysis and Exploration:**
# Objective: Explore the dataset to understand patterns and relationships within the job listings.
# Analysis: Analyze job listings by company, experience level, salary range, required skills, and location data.
# Visualizations: Utilize various charts (bar, pie, box, word cloud) to visualize the data and gain insights.
# 4. **Insights Gained:**
# Job Listings by Company: Identified top companies with the most job listings.
# Job Listings by Experience Level: Explored the distribution of job listings based on experience requirements.
# Salary Ranges: Analyzed the distribution of salary ranges.
# Skills Required: Visualized the most frequently mentioned skills in job listings.
# Location Data: Explored regional job distribution trends.
#
# ### **Conclusion:**
# **For Job Seekers:** Focus on companies with the most job listings, tailor applications based on popular skills and experience levels, and research salary expectations within the industry.
#
# **For Employers/Recruiters:**Tailor job descriptions to match popular skills and experience levels, adjust salary offerings based on industry norms, and consider regional job distribution trends for recruitment strategies.
